# %% [markdown]
# ## LinkedIn Profile Scrapper in Python

# %% [markdown]
# Watch-> LinkedIn Auto Connect Bot with Personalized Messaging: https://www.youtube.com/watch?v=d6EQnjj-Bx0

# %% [markdown]
# Watch Video for this file: https://youtu.be/QVnBCtgS_-U

# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
browser = webdriver.Chrome('driver/chromedriver.exe')
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]


elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)

elementID.submit()

# %%
link = 'https://www.linkedin.com/in/rishabh-singh-61b706114/'
# link = 'https://www.linkedin.com/in/simran-gandhi-024593128/'
# link = 'https://www.linkedin.com/in/smriti-handa-0636045/'
# link = 'https://www.linkedin.com/in/charan-nadendla-858a17120/'
# link = 'https://www.linkedin.com/in/mayank-agrawal-1a5883148/'
browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Rishabh Singh | LinkedIn</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="true" name="is-http2"/>
# <meta content="notranslate" name="google"/>
# <link href="/voyager/manifest.json" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/tnh7n50m7at20lpvirnxtpe" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%22voyager-web_1.5.2297%2Bf1081619%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22phone_web%22%7D%2C%22impression%22%3A%7B%22timeThreshold%22%3A300%2C%22percentageThreshold%22%3A50%2C%22viewportOffset%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%7D%2C%22comScore%22%3A%7B%22enabled%22%3Atrue%7D%7D%2C%22defaultRootMargin%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%2C%22skeleton%22%3A%7B%22data%22%3A%7B%7D%2C%22template%22%3A%22.%2Fskeleton%2Floader.hbs%22%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets%2Fimg%2Fchina-icp-filing.png%22%2C%22assets%2Fimg%2Forganization%2Fdesktop-screenshot.png%22%2C%22assets%2Fimg%2Forganization%2Fmobile-screenshot.png%22%2C%22assets%2Fimg%2Fprofile%2Fdesktop-photo-upload-add-photo.png%22%2C%22assets%2Fhighcharts%2Fhighcharts.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Fmap.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Faccessibility.js%22%2C%22assets%2Fmedia-player%2Fmedia-player.amd.js%22%2C%22assets%2FcloudSDK%2FOneDriveSDK.js%22%2C%22assets%2FcloudSDK%2FDropboxSDK.js%22%2C%22assets%2Fproj4.js%22%2C%22assets%2Fspectroscopy-worker.js%22%2C%22assets%2Fworld.js%22%2C%22assets%2Fsrc%2Fchartbeat.js%22%2C%22assets%2Ffavicon.ico%22%2C%22assets%2Ffavicon-notification.ico%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_posting_job_description_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_posting_screening_questions_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_posting_add_budget_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_posting_applicant_management_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_posting_recommended_matches_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_featured_applicant_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_inmail_650x468_v1.png%22%2C%22assets%2 ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <link href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" id="favicon-ico" rel="shortcut icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/3l4lmvgby04f9qzhrrkrkexni" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/9gfkhi67jtvq9r1h13pgkpmsb" rel="stylesheet"/>
# <meta content='{"assets/img/china-icp-filing.png":"https://static-exp1.licdn.com/sc/h/cbn91jpp9vuid7olk3y6qmbpj","assets/img/organization/desktop-screenshot.png":"https://static-exp1.licdn.com/sc/h/ev2ewp91pnvtl0gcyt4xht0b5","assets/img/organization/mobile-screenshot.png":"https://static-exp1.licdn.com/sc/h/3v3wzhnr3kapuzwpk1zt6r1jt","assets/img/profile/desktop-photo-upload-add-photo.png":"https://static-exp1.licdn.com/sc/h/c5ybm82ti04zuasz2a0ubx7bu","assets/highcharts/highcharts.js":"https://static-exp1.licdn.com/sc/h/br/jbevef2eshsf90hs9udzeno3","assets/highcharts/modules/map.js":"https://static-exp1.licdn.com/sc/h/br/f0tjc5q9eq9sc2me2wuptv5ab","assets/highcharts/modules/accessibility.js":"https://static-exp1.licdn.com/sc/h/br/8gq9abeur2x3h4h1h0v7j79r7","assets/media-player/media-player.amd.js":"https://static-exp1.licdn.com/sc/h/br/d5hucpjgqj7v1rcydsi1p6msd","assets/cloudSDK/OneDriveSDK.js":"https://static-exp1.licdn.com/sc/h/br/45bhd02gokyndidefhx1ptdvt","assets/cloudSDK/DropboxSDK.js":"https://static-exp1.licdn.com/sc/h/br/874gdyhk2zgt1hdrm1rvxih7g","assets/proj4.js":"https://static-exp1.licdn.com/sc/h/br/bssifg7wab7eud19hs9osdhm4","assets/spectroscopy-worker.js":"https://static-exp1.licdn.com/sc/h/br/730slndhwq0v1l8o32boe3r31","assets/world.js":"https://static-exp1.licdn.com/sc/h/br/2s51vhg4vrr7k24sjaop3o56b","assets/src/chartbeat.js":"https://static-exp1.licdn.com/sc/h/br/dyfaibv269h5yw50ns9nh0rzu","assets/favicon.ico":"https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca","assets/favicon-notification.ico":"https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc","assets/img/premium/products/slides/job_posting_job_description_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/d3e5mebaq0cjbb7baxxfn7cpn","assets/img/premium/products/slides/job_posting_screening_questions_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/o0e740l1phn0atidsozfklqy","assets/img/premium/products/slides/job_posting_add_budget_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/bbferoltnl23sq9kcq5ert24x","assets/img/premium/products/slides/job_posting_applicant_management_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/8j2vhfhm7t4ovh0yhggv3eskf","assets/img/premium/products/slides/job_posting_recommended_matches_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/d1jhpk4wntmtf9c6kcbrk83xr","assets/img/premium/products/slides/job_seeker_featured_applicant_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/6gl4ufmcgffyhuu4lti3us9mr","assets/img/premium/products/slides/job_seeker_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/194ufzr1ibusivbechyc149ox","assets/img/premium/products/slides/job_seeker_job_insights_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b9qvh5p1l68rq61pvb6f3dpin","assets/img/premium/products/slides/job_seeker_professional_learning_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/75zb38b8070xlgfvx5ta8ksg5","assets/img/premium/products/slides/job_seeker_professional_wvmp_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/85swj4u5h27rp1gv0gtu5568","assets/img/premium/products/slides/job_seeker_resume_builder_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b7ybzpxcq6ma06b6jrssqcu5v","assets/img/premium/products/slides/job_seeker_interview_prep_648x468_v1.png":"https://static-exp1.licdn.com/sc/h/dxj16dv0q0dlpveh17ftnocke","assets/img/premium/products/slides/professional_browse_profiles_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/1ehgbakjab9ljkoavygzhtoa3","assets/img/premium/products/slides/professional_company_research_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/2wxmom0vvkzhp4tfdd0cpa4ib","assets/img/premium/products/slides/professional_company_research_650x468_v2.png":"https://static-exp1.licdn.com/sc/h/5tigosoe1c6tonlu9psklh2f3","assets/img/premium/products/slides/professional_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/cwcgp1ebxedyejqr826bkpu8v","assets/img/premium/products/slides/recruiter_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/esja ...
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static-exp1.licdn.com/sc/h/br/aanly5o5blk5l977rvjksluux" name="i18nIntlPolyfillUrl"/>
# <meta content="in" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;VL5seya9RMm4S5K5RxmPaQ==" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.5.2297", "trackingId": [3, 124, 88, -70, -90, 4, 72, 19, -65, 114, -72, 95, -69, -94, -105, 40]}' name="applicationInstance"/>
# <meta content="qOR554UYRP623LiOSKrOaQ==" name="clientPageInstanceId"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lix":{"voyager.web.nav.job-posting-jobs-led-entry-points":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.nav.job-posting-jobs-led-entry-points"},"voyager.iac.web.import-communities":{"treatment":"control","trackingInfo":null,"testKey":"voyager.iac.web.import-communities"},"voyager.web.participate-directed-posting":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.participate-directed-posting"},"voyager.launchpad.web.extended.add-photo.social-proof.facebook-upload":{"treatment":"control","trackingInfo":{"segmentIndex":0,"treatmentIndex":0,"experimentId":2248661,"urn":"urn:li:member:765646733"},"testKey":"voyager.launchpad.web.extended.add-photo.social-proof.facebook-upload"},"voyager.infra.web.not-mobile-user":{"treatment":"treatment","trackingInfo":null,"testKey":"voyager.infra.web.not-mobile-user"},"voyager.web.premium.job-details-expert-promo":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.premium.job-details-expert-promo"},"voyager.web.jobs-post-apply-jedi":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":2322117,"urn":"urn:li:member:765646733"},"testKey":"voyager.web.jobs-post-apply-jedi"},"publishing.web.filtered-image-history":{"treatment":"enabled","trackingInfo":null,"testKey":"publishing.web.filtered-image-history"},"voyager.profile.web.dash.edit.p4":{"treatment":"control","trackingInfo":null,"testKey":"voyager.profile.web.dash.edit.p4"},"voyager.profile.web.dash.edit.p2":{"treatment":"control","trackingInfo":null,"testKey":"voyager.profile.web.dash.edit.p2"},"voyager.video.web.settings-modal":{"treatment":"captions","trackingInfo":null,"testKey":"voyager.video.web.settings-modal"},"voyager.organization.lcp.web.enable-employee-content-feed":{"treatment":"control","trackingInfo":null,"testKey":"voyager.organization.lcp.web.enable-employee-content-feed"},"voyager.profile.web.dash.edit.p1":{"treatment":"control","trackingInfo":null,"testKey":"voyager.profile.web.dash.edit.p1"},"voyager.web.messaging-overlay-discoverability":{"treatment":"color-and-photo","trackingInfo":{"segmentIndex":1,"treatmentIndex":1,"experimentId":2109756,"urn":"urn:li:member:765646733"},"testKey":"voyager.web.messaging-overlay-discoverability"},"voyager.web.search-extended-loading-template":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.search-extended-loading-template"},"voyager.ignite.web.slideshare-migration":{"treatment":"control","trackingInfo":null,"testKey":"voyager.ignite.web.slideshare-migration"},"voyager.web.engage-revenue-mobile-web-link-nesting":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.engage-revenue-mobile-web-link-nesting"},"voyager.profile.web.dash.view":{"treatment":"control","trackingInfo":{"segmentIndex":2,"treatmentIndex":0,"experimentId":2252324,"urn":"urn:li:member:765646733"},"testKey":"voyager.profile.web.dash.view"},"voyager.web.infra-ux-new-global-nav":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.infra-ux-new-global-nav"},"voyager.mynetwork.web.segments-businesscards":{"treatment":"control","trackingInfo":{"segmentIndex":4,"treatmentIndex":0,"experimentId":2304263,"urn":"urn:li:member:765646733"},"testKey":"voyager.mynetwork.web.segments-businesscards"},"voyager.web.organization.home-about-redesign":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.organization.home-about-redesign"},"voyager.web.profile.open-to-tooltip":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":2333954,"urn":"urn:li:member:765646733"},"testKey":"voyager.web.profile.open-to-tooltip"},"voyager.onboarding.web.job-alert-landing":{"treatment":"control","trackingInfo":{"segmentIndex":0,"treatmentIndex":0,"experimentId":2352401,"urn":"urn:li:member:765646733"},"testKey":"voyager.onboarding.web.job-alert-landing"},"voyager.nav.web.lang-country-sales-solutions-link":{"treatment":"control","trackingInfo":null,"testKey":"voyager. ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/bdlq6obtyvgt99yahmzx9ii86"></script>
# <meta content="voyager-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.5.2297" name="serviceVersion"/>
# <meta content="uNTIcQCQyRWQk1lY238AAA==" name="treeID"/>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="colleagues/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%7D" name="events/config/environment"/>
# <meta content="%7B%7D" name="feed/config/environment"/>
# <meta content="%7B%7D" name="feed-detail/config/environment"/>
# <meta content="%7B%7D" name="feed-shared/config/environment"/>
# <meta content="%7B%7D" name="groups/config/environment"/>
# <meta content="%7B%7D" name="hiring/config/environment"/>
# <meta content="%7B%7D" name="inshare/config/environment"/>
# <meta content="%7B%7D" name="interview-prep/config/environment"/>
# <meta content="%7B%7D" name="jobs/config/environment"/>
# <meta content="%7B%22googleAnalytics%22%3A%7B%22trackingId%22%3A%22UA-62256447-1%22%7D%7D" name="jobs-search/config/environment"/>
# <meta content="%7B%7D" name="lead-capture/config/environment"/>
# <meta content="%7B%7D" name="me/config/environment"/>
# <meta content="%7B%7D" name="me-ca/config/environment"/>
# <meta content="%7B%7D" name="messaging/config/environment"/>
# <meta content="%7B%7D" name="msg-conversation-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-mentions/config/environment"/>
# <meta content="%7B%7D" name="msg-overlay/config/environment"/>
# <meta content="%7B%7D" name="msg-referrals/config/environment"/>
# <meta content="%7B%7D" name="msg-rich-media/config/environment"/>
# <meta content="%7B%7D" name="msg-shared-modals/config/environment"/>
# <meta content="%7B%7D" name="msg-spinmail/config/environment"/>
# <meta content="%7B%7D" name="msg-ui/config/environment"/>
# <meta content="%7B%7D" name="mynetwork/config/environment"/>
# <meta content="%7B%7D" name="news/config/environment"/>
# <meta content="%7B%7D" name="notifications/config/environment"/>
# <meta content="%7B%7D" name="onboarding/config/environment"/>
# <meta content="%7B%7D" name="opportunities/config/environment"/>
# <meta content="%7B%7D" name="organization/config/environment"/>
# <meta content="%7B%7D" name="organization-about/config/environment"/>
# <meta content="%7B%7D" name="organization-admin/config/environment"/>
# <meta content="%7B%7D" name="organization-at-your-org/config/environment"/>
# <meta content="%7B%7D" name="organization-content-suggestions/config/environment"/>
# <meta content="%7B%7D" name="organization-insights/config/environment"/>
# <meta content="%7B%7D" name="organization-life/config/environment"/>
# <meta content="%7B%7D" name="organization-people/config/environment"/>
# <meta content="%7B%7D" name="organization-salary/config/environment"/>
# <meta content="%7B%7D" name="participate-text-editor/config/environment"/>
# <meta content="%7B%7D" name="premium/config/environment"/>
# <meta content="%7B%7D" name="profile/config/environment"/>
# <meta content="%7B%7D" name="profile-edit/config/environment"/>
# <meta content="%7B%7D" name="profile-ge/config/environment"/>
# <meta content="%7B%7D" name="profile-opportunities/config/environment"/>
# <meta content="%7B%7D" name="profile-search-analytics/config/environment"/>
# <meta content="%7B%7D" name="profile-skill-assessments/config/environment"/>
# <meta content="%7B%7D" name="profile-subroutes/config/environment"/>
# <meta content="%7B%7D" name="publishing/config/environment"/>
# <meta content="%7B%7D" name="resume-builder/config/environment"/>
# <meta content="%7B%7D" name="salary/config/environment"/>
# <meta content="%7B%7D" name="school/config/environment"/>
# <meta content="%7B%7D" name="search/config/environment"/>
# <meta content="%7B%7D" name="showcase/config/environment"/>
# <meta content="%7B%7D" name="slideshare-migration/config/environment"/>
# <meta content="%7B%7D" name="unemployment/config/environment"/>
# <meta content="%7B%7D" name="video-engine/config/environment"/>
# <meta content="https://static-exp1.licdn.com/sc/h/3lfh8bp15apmrtgzs3mgjhfhe" id="artdeco/static/images/icons.svg" name="asset-url"/>
# <meta content='{"bundles":{"abi":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/1yndixv6v2teumpwjrydcz5i3"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/dp7ybv6urx6u20hohxz14zr8x"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/5rip5bzsa5d273pzft75m1amu"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/cxvxz3y2giqil2skpiuwtwng3"}],"dependencies":["msg-ui"]},"article-reader":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/a0jdg9xrtdy0qaabom790u7r2"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/9xh5x26jkzuxfzfrb0cytpefm"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/7lql4gathockp5afh1esz51ba"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/bcvn8v3j33sn7m979ycf1mx78"}],"dependencies":["feed-shared"]},"colleagues":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/f54w830gmighsr1am03q14rgd"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/9ofqe09lgvd9zzqa4j8lvkv3c"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/8ir1bab1hxl3f18nm3r84t4ca"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/460q5eabtypnuh3vv58hrs2k3"}],"dependencies":[]},"company-creation":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/3xppofoyte93ab7qtxb9h9fk7"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/648i151ij7botk3iwptapk2rl"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/18yn5f5j5uczcjdtnkc9d7ft8"}],"dependencies":[]},"events":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/9xf13hhe51s3jrgtlwcv4r6m"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/993i14wmu27356p7dr8la11fx"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/475iytdoqbz7ndzi4twambfnn"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/13nd92rawy13vgrmutx42cxbz"}],"dependencies":["feed-shared"]},"feed-detail":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/gj305khe6wnfgktmm2awcqsq"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/2mcqqbnib8zikkaoas3sbzbwv"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/50biyycawjbpqsomclvqfcuws"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/5fz44udcxg84ear3340ek7lkf"}],"dependencies":["feed","feed-shared","msg-ui"]},"feed-shared":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/k1z57sm92b1xt7naxoa8m1qg"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/3obw4e35a0x2yc6descajz7if"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/3538uw2yl8gl9usuapubljhdi"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/dh20sil95uzh3ubeek718kv9a"}],"dependencies":null},"feed":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/8y5qu29y5pg1045hxt6de3b56"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/chjmm785174wmz5zip7t0or1u"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/8ufbkiu0sqg8l6w57hindu05s"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/crn72mk4bc3h40iyqjvv3mq08"}],"dependencies":["feed-shared","msg-ui"]},"groups":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/dlw3e0r7jk0lpoche01yo7o40"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/3ta90tpa8lo63jrfh9vqaiuky"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/8ctyptczci9k0u2jelgirptwf"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/25luckxfgzt61pg3zhrpd94ji"}],"dependencies":["feed-shared"]},"hiring":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/axyegl44aiiqohzdx8166wae"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/by5vzi7ib5vat3711nb7gub88"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/1wjy4sgs5dfrbhg5c3ivl9645"}],"dependencies":[]},"inshare":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/57uvm5bexertaqb7pke4kw6af"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/b ...
# <link href="https://static-exp1.licdn.com/sc/h/br/67xg0dpfl2pv3thvcotb34y10" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/2am44wklac8vt2ek0l0ww4bdv" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/3obw4e35a0x2yc6descajz7if" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/dh20sil95uzh3ubeek718kv9a" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/3sl0gg52kldxvxc5hwxyp0cob" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/df3tj5lshhkcgu3ytk01xpzup" rel="stylesheet"/>
# <link class="lazy-css" href="https://static-exp1.licdn.com/sc/h/br/1vs386214dgcsow81mark7ukn" rel="stylesheet"/>
# <style></style>
# <meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://in/rishabh-singh-61b706114/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/cr1spid3dx0jhsotjvvpq17pw"></script><link href="https://static-exp1.licdn.com/sc/h/br/coi4tsaobccxjqh2jcplr10fl" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/dwxpjw87d8cnswvlonm6bxdd6"></script><link href="https://static-exp1.licdn.com/sc/h/br/f1iiegpyuv75d53ij0vltrx0l" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/coa7f3ykpl4n59lxspa6n42h5"></script><script src="https://static-exp1.licdn.com/sc/h/br/ajwduuzuc2uxkt936gz14ewn9"></script><link href="https://static-exp1.licdn.com/sc/h/br/dalt1lftyvw2im5ekwxyswnic" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/6chggj41dleecmw8h4lj54nen"></script><link href="https://static-exp1.licdn.com/sc/h/br/aezwn80kvbir57b8hkxn3gtth" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/4tjdrkap0gpo44ze119l77rls"></script><link href="https://static-exp1.licdn.com/sc/h/br/4x8ocdykq85sxps7fx9idza4j" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/2kqi2lrwplhbhjwpihlfcs1d6"></script></head>
# <body class="render-mode-BIGPIPE nav-v2 ember-application boot-complete icons-loaded" data-t-link-to-event-attached="true" dir="ltr">
# <!-- HUED-11420 -->
# <div id="artdeco-toasts__wormhole"> <section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h1 class="artdeco-toasts__title">
#         0 notifications total
#       </h1>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>
# </div>
# <div id="a11y-menu"> <div>
# <div class="a11y-menu-container ember-view" id="ember12"><label class="jump-menu-label t-14 t-black--light t-bold" for="a11y-jump-menu-trigger">Jump to:</label>
# <div class="dropdown closed ember-view" id="a11y-jump-menu"><button aria-controls="a11y-jump-menu-options" aria-expanded="false" class="dropdown-trigger ember-view" id="a11y-jump-menu-trigger" type="button">    Select option
# </button> <div class="dropdown-overflow">
# <ul class="dropdown-options ember-view" id="a11y-jump-menu-options" style="display: none;"><!-- --></ul> </div>
# </div>
# <button class="mr4 artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember16"><!-- -->
# <span class="artdeco-button__text">
#     Skip to search
# </span></button>
# <a class="artdeco-button artdeco-button--muted artdeco-button--secondary" data-ember-action="" data-ember-action-17="17" href="#skip-link">
#   Skip to main content
# </a>
# <button class="a11y-menu__close artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view" id="ember18"> <li-icon aria-hidden="true" class="artdeco-button__icon" type="cancel-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="large-icon" d="M20,5.32L13.32,12,20,18.68,18.66,20,12,13.33,5.34,20,4,18.68,10.68,12,4,5.32,5.32,4,12,10.69,18.68,4Z" style="fill: currentColor"></path></svg></li-icon>
# <span class="artdeco-button__text">
#     Close jump menu
# </span></button>
# </div>
# </div>
# </div><header class="extended-nav nav-main-container global-alert-offset-top" id="extended-nav" role="banner" style="display: block;" tabindex="-1"><div class="nav-main__content full-height display-flex align-items-center"><div class="nav-main__inbug-container"><div class="nav-item--inbug" id="inbug-nav-item" lang="en"><a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__icon nav-item__icon--inbug" lang="en" role="presentation"><li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 2 ...
# <div class="search-global-typeahead ember-view" id="ember32"><div class="search-typeahead-v2 search-global-typeahead__typeahead ember-view" id="global-nav-typeahead"> <div>
# <!-- --> <div class="ember-view" id="ember34"><input aria-activedescendant="" aria-autocomplete="list" aria-expanded="false" aria-label="Search" aria-owns="" class="search-global-typeahead__input" placeholder="Search" role="combobox" type="text"/></div>
# </div>
# <!-- -->
# </div><div class="search-global-typeahead__controls">
# <button class="search-typeahead-v2__button search-global-typeahead__button" data-control-name="nav.search_button" data-ember-action="" data-ember-action-35="35" tabindex="-1">
# <li-icon aria-label="i18n_search_button" class="search-global-typeahead__icon" role="img" size="medium" type="search-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="large-icon" d="M21,19.67l-5.44-5.44a7,7,0,1,0-1.33,1.33L19.67,21ZM10,15.13A5.13,5.13,0,1,1,15.13,10,5.13,5.13,0,0,1,10,15.13Z" style="fill: currentColor"></path></svg></li-icon>
# </button>
# </div>
# </div>
# </div>
# </div></div></form><nav aria-label="Primary" class="display-flex full-height" data-nav="main"><ul class="nav-main nav-container display-flex full-height"><li class="nav-item nav-item--feed" id="feed-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__badge nav-item__badge--doughnut"><span aria-hidden="true" class="nav-item__badge-count">3</span><span class="visually-hidden">3</span></span><span class="nav-item__icon" id="feed-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-home-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M22,8.45L12.85,2.26a1.5,1.5,0,0,0-1.69,0L2,8.45,3.06,10,4,9.37V19a1,1,0,0,0,1,1h5V15h4v5h5a1,1,0,0,0,1-1V9.37L20.94,10Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M22,9.45L12.85,3.26a1.5,1.5,0,0,0-1.69,0L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h6V16h2v5h6a1,1,0,0,0,1-1V10.37L20.94,11ZM18,19H15V15a1,1,0,0,0-1-1H10a1,1,0,0,0-1,1v4H6V8.89l6-4,6,4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">Home</span></a></li><li class="nav-item nav-item--mynetwork" id="mynetwork-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="relationships" data-control-name="" data-link-to="mynetwork" data-resource="voyagerCommunicationsTabBadges" href="/mynetwork/"><span class="nav-item__icon" id="mynetwork-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-people-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M16,17.85V20a1,1,0,0,1-1,1H1a1,1,0,0,1-1-1V17.85a4,4,0,0,1,2.55-3.73l2.95-1.2V11.71l-0.73-1.3A6,6,0,0,1,4,7.47V6a4,4,0,0,1,4.39-4A4.12,4.12,0,0,1,12,6.21V7.47a6,6,0,0,1-.77,2.94l-0.73,1.3v1.21l2.95,1.2A4,4,0,0,1,16,17.85Zm4.75-3.65L19,13.53v-1a6,6,0,0,0,1-3.31V9a3,3,0,0,0-6,0V9.18a6,6,0,0,0,.61,2.58A3.61,3.61,0,0,0,16,13a3.62,3.62,0,0,1,2,3.24V21h4a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.75,14.2Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M20.74,14.2L19,13.54V12.86l0.25-.41A5,5,0,0,0,20,9.82V9a3,3,0,0,0-6,0V9.82a5,5,0,0,0,.75,2.63L15,12.86v0.68l-1,.37a4,4,0,0,0-.58-0.28l-2.45-1V10.83A8,8,0,0,0,12,7V6A4,4,0,0,0,4,6V7a8,8,0,0,0,1,3.86v1.84l-2.45,1A4,4,0,0,0,0,17.35V20a1,1,0,0,0,1,1H22a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.74,14.2ZM16,8.75a1,1,0,0,1,2,0v1.44a3,3,0,0,1-.38,1.46l-0.33.6a0.25,0.25,0,0,1-.22.13H16.93a0.25,0.25,0,0,1-.22-0.13l-0.33-.6A3,3,0,0,1,16,10.19V8.75ZM6,5.85a2,2,0,0,1,4,0V7.28a6,6,0,0,1-.71,2.83L9,10.72a1,1,0,0,1-.88.53H7.92A1,1,0,0,1,7,10.72l-0.33-.61A6,6,0,0,1,6,7.28V5.85ZM14,19H2V17.25a2,2,0,0,1,1.26-1.86L7,13.92v-1a3,3,0,0,0,1,.18H8a3,3,0,0,0,1-.18v1l3.72,1.42A2,2,0,0,1,14,17.21V19Zm7,0H16V17.35a4,4,0,0,0-.55-2l1.05-.4V14.07a2,2,0,0,0,.4.05h0.2a2,2,0,0,0,.4-0.05v0.88l2.53,1a1.5,1.5,0,0,1,1,1.4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">My Network</span></a></li><li class="nav-item nav-item--jobs" id="jobs-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="jobs" data-resource="" href="/jobs/"><span class="nav-item__icon" id="jobs-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-jobs-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M2,13H22v6a1,1,0,0,1-1,1H3a1,1,0,0,1-1-1V13ZM22,8v4H2V8A1,1,0, ...
# <div class="dropdown closed ember-view" id="nav-settings__dropdown"><button aria-controls="nav-settings__dropdown-options" aria-expanded="false" class="t-14 t-black--light t-bold nav-item__link dropdown-trigger ember-view" data-control-name="nav.settings" id="nav-settings__dropdown-trigger" type="button"> <img alt="KGP Talkie" class="nav-item__profile-member-photo nav-item__icon ember-view" height="24" id="ember29" src="https://media.licdn.com/dms/image/C5103AQEkJUJ02qVLEw/profile-displayphoto-shrink_100_100/0?e=1575504000&amp;v=beta&amp;t=6LbVOj1WmX_AQAEoNqZ0YmA7s7UP4-phBh16YbHdmmk" width="24"/>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Me</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="small-icon" d="M8.8,10.66L14,5.12A0.07,0.07,0,0,0,13.93,5H2.07A0.07,0.07,0,0,0,2,5.12L7.2,10.66A1.1,1.1,0,0,0,8.8,10.66Z" style="fill-opacity: 1"></path></svg></li-icon>
# </div>
# </button>
# <ul class="dropdown-options nav-settings__dropdown-options ember-view" id="nav-settings__dropdown-options" style="display: none;"><!-- --></ul>
# </div>
# </div>
# </li><li class="nav-item nav-item--app-launcher" id="app-launcher-nav-item"> <div class="nav-item__content">
# <div class="ember-view" id="ember23"><button class="nav-item__link nav-panel__trigger" data-control-name="nav.launcher" data-ember-action="" data-ember-action-24="24">
# <li-icon aria-label="Work icon" class="nav-item__icon" role="img" type="grid-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="large-icon" d="M10,10h4v4H10V10Zm0,11h4V17H10v4ZM3,14H7V10H3v4Zm0,7H7V17H3v4ZM3,7H7V3H3V7Zm14,7h4V10H17v4ZM17,3V7h4V3H17ZM10,7h4V3H10V7Zm7,14h4V17H17v4Z" style="fill: currentColor"></path></svg></li-icon>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Work</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="small-icon" d="M8.8,10.66L14,5.12A0.07,0.07,0,0,0,13.93,5H2.07A0.07,0.07,0,0,0,2,5.12L7.2,10.66A1.1,1.1,0,0,0,8.8,10.66Z" style="fill-opacity: 1"></path></svg></li-icon>
# </div>
# </button>
# <div class="ember-view" id="ember25"><!-- --></div></div> </div>
# </li><li class="nav-item nav-item--spotlight-one nav-item__spotlight" id="spotlight-one-nav-item">
# <div class="nav-item__wormhole">
# <div class="nav-item__content t-14 t-black t-normal premium-upsell-link ember-view" id="ember20">
# <a class="link-without-visited-state nav-item__spotlight-upsell premium-upsell-link--long ember-view" data-control-name="premium_nav_upsell_text_click" href="/premium/products/?destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Fin%2Frishabh-singh-61b706114%2F%3FshowPremiumWelcomeBanner%3Dtrue&amp;upsellOrderOrigin=premium_nav_upsell_text" id="ember21">        Try Premium Free for 1 Month
# <!-- --></a></div>
# </div>
# </li></ul></nav></div></header>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <script src="https://static-exp1.licdn.com/sc/h/br/dfxnl2dpcq6evhxrj95wceh60"></script>
# <script nomodule="" src="https://static-exp1.licdn.com/sc/h/br/8igq682aqf4nsndn4l839zjf1"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/44lpm3xommt4uaobb0rsjjk0w"></script>
# <div class="app-boot-bg-skeleton" id="app-boot-bg-loader">
# <div class="top-bar"></div>
# <div class="content">
# <div class="initial-load-animation fade-load">
# <div class="linkedin-image">
# <li-icon aria-hidden="true" color="brand" size="48dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-28dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0" fill="#FFFFFF"></path><path ...
# </div>
# <div class="loading-bar">
# <div class="blue-bar"></div>
# </div>
# </div>
# </div>
# </div>
# <script src="https://static-exp1.licdn.com/sc/h/br/comvpvwbrbupznqercou0ughs"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/e1bcfqxm9slmyxf9xfu2uctah"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/85dfwd20y5ignc6k3yvwfobit"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/cfxxsf0dnjf33v09c6ai5izej"></script><script src="https://static-exp1.licdn.com/sc/h/br/e1tsh0ekqw9dotqc18diwzsjy"></script><script src="https://static-exp1.licdn.com/sc/h/br/k1z57sm92b1xt7naxoa8m1qg"></script><script src="https://static-exp1.licdn.com/sc/h/br/3538uw2yl8gl9usuapubljhdi"></script><script src="https://static-exp1.licdn.com/sc/h/br/1yj3yg689hbim1xs9jnmoe5uh"></script><script src="https://static-exp1.licdn.com/sc/h/br/6gk2xxjy64l6lrbq2yuiklwdf"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/73771ry6h1z2etmlruvyg41b7"></script>
# <div id="artdeco-modal-outlet"></div>
# <code id="bpr-guid-2140046" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:uPYuDSPXzooiHx+zPOguG1+f+JFMWTWFEfhiIQtEFMM=","elements":[],"paging":{"count":10,"start":0,"total":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140046" style="display: none">
#   {"request":"/voyager/api/takeovers","status":200,"body":"bpr-guid-2140046"}
# </code>
# <img class="datalet-bpr-guid-2140046" src="..." style="display: none"/><code id="bpr-guid-2140047" style="display: none">
#   {"data":{"canBrowseProfiles":false,"reactivationFeaturesEligible":false,"canViewJobAnalytics":false,"canViewWVMP":false,"premiumFreeTrialEligible":true,"canAccessLearningVideos":false,"premiumLearningUpgradeEligible":false,"canViewCompanyInsights":false,"$type":"com.linkedin.voyager.premium.FeatureAccess"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140047" style="display: none">
#   {"request":"/voyager/api/premium/featureAccess?name\u003DreactivationFeaturesEligible","status":200,"body":"bpr-guid-2140047"}
# </code>
# <img class="datalet-bpr-guid-2140047" src="..." style="display: none"/><code id="bpr-guid-2140048" style="display: none">
#   {"data":{"memberGroup":"FREE","companies":[],"showStaticLearning":false,"$type":"com.linkedin.voyager.common.Nav"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140048" style="display: none">
#   {"request":"/voyager/api/nav","status":200,"body":"bpr-guid-2140048"}
# </code>
# <img class="datalet-bpr-guid-2140048" src="..." style="display: none"/><code id="bpr-guid-2140049" style="display: none">
#   {"data":{"shareVisibilityType":"PUBLIC","sharePublicVisibilityTooltipMessage":null,"entityUrn":"urn:li:fs_mySettings:765646733","dailyRundownPushNotificationAllowed":false,"viewProfilePhoto":"EVERYONE","videoAutoPlay":"ALWAYS","flagshipCrossLinkToJobSearchApp":true,"discloseAsProfileViewer":"DISCLOSE_FULL","mobileCalendarsAutoSyncAllowed":true,"mobileContactsAutoSyncAllowed":true,"$type":"com.linkedin.voyager.common.MySettings"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140049" style="display: none">
#   {"request":"/voyager/api/me/settings","status":200,"body":"bpr-guid-2140049"}
# </code>
# <img class="datalet-bpr-guid-2140049" src="..." style="display: none"/><code id="bpr-guid-2140050" style="display: none">
#   {"data":{"messagingTypingIndicators":"ALL_DISABLED","allowOpenProfile":false,"profilePictureVisibilitySetting":"PUBLIC","entityUrn":"urn:li:fs_privacySettings:ACoAAC2i140Bsj24FkkQqrAlach8DCc-TVS2zpA","showPublicProfile":true,"showPremiumSubscriberBadge":false,"publicProfilePictureVisibilitySetting":"PUBLIC","formerNameVisibilitySetting":"PUBLIC","messagingSeenReceipts":"ALL_DISABLED","allowProfileEditBroadcasts":true,"$type":"com.linkedin.voyager.identity.profile.PrivacySettings"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140050" style="display: none">
# ...
# <div class="ember-view" id="ember284"><artdeco-dropdown class="global-footer-dropdown dropdown ember-view" id="ember285"><button aria-expanded="false" class="global-footer-dropdown__trigger ember-view" data-control-name="globalfooter.privacy" id="globalfooter-privacy_dropdown-trigger" placement="top" role="button" tabindex="0"> <span class="global-footer__link global-footer__link--static t-12 t-bold">
#       Privacy &amp; Terms
#       <li-icon aria-hidden="true" class="global-footer-dropdown__trigger-icon" size="small" type="chevron-down-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="small-icon" d="M8,9l5.93-4L15,6.54l-6.15,4.2a1.5,1.5,0,0,1-1.69,0L1,6.54,2.07,5Z" style="fill-opacity: 1"></path></svg></li-icon>
# </span>
# <!-- --></button><artdeco-dropdown-content aria-hidden="true" class="global-footer-dropdown__options ember-view" data-dropdown="" id="ember287" justification="left" placement="top" tabindex="-1"> <ul>
# <li class="global-footer-dropdown__item" id="privacy-policy-footer-link">
# <a class="block pv1 ph4 t-12 ember-view" href="https://www.linkedin.com/static?key=privacy_policy" id="ember289" rel="noopener noreferrer" target="_blank">                Privacy Policy
# </a> </li>
# <li class="global-footer-dropdown__item" id="user-agreement-footer-link">
# <a class="block pv1 ph4 t-12 ember-view" href="https://www.linkedin.com/static?key=user_agreement" id="ember291" rel="noopener noreferrer" target="_blank">                User Agreement
# </a> </li>
# <li class="global-footer-dropdown__item" id="cookie-policy-footer-link">
# <a class="block pv1 ph4 t-12 ember-view" href="https://www.linkedin.com/legal/cookie-policy" id="ember293" rel="noopener noreferrer" target="_blank">                Cookie Policy
# </a> </li>
# <li class="global-footer-dropdown__item" id="copyright-policy-footer-link">
# <a class="block pv1 ph4 t-12 ember-view" href="https://www.linkedin.com/static?key=copyright_policy" id="ember295" rel="noopener noreferrer" target="_blank">                Copyright Policy
# </a> </li>
# <li class="global-footer-dropdown__item" id="ad-choices-footer-link">
# <a class="block pv1 ph4 t-12 ember-view" href="https://www.linkedin.com/help/linkedin/answer/62931" id="ember297" rel="noopener noreferrer" target="_blank">                Ad Choices
# </a> </li>
# </ul>
# </artdeco-dropdown-content></artdeco-dropdown></div>
# </li>
# <li class="global-footer__resources-item global-footer__resources-item--advertising-solutions">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.advertising" href="https://www.linkedin.com/ad/start?trk=n_nav_ads_f" id="globalfooter-advertising" rel="noopener noreferrer" target="_blank"> <span>Advertising</span>
# </a> </li>
# <li class="global-footer__resources-item global-footer__resources-item--sales-solutions">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.sales_solutions" href="https://business.linkedin.com/sales-solutions?trk=flagship_nav&amp;veh=li-footer-lss-control&amp;src=li-footer" id="globalfooter-sales_solutions" rel="noopener noreferrer" target="_blank"> <span>Sales Solutions</span>
# </a> </li>
# <li class="global-footer__resources-item global-footer__resources-item--mobile">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.mobile" href="https://mobile.linkedin.com/" id="globalfooter-mobile" rel="noopener noreferrer" target="_blank"> <span>Mobile</span>
# </a> </li>
# <li class="global-footer__resources-item global-footer__resources-item--small-business">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.small_business" href="https://smallbusiness.linkedin.com?&amp;src=li-footer" id="globalfooter-small_business" rel="noopener noreferrer" target="_blank"> <span>Small Business</span>
# </a> </li>
# <li class="global-footer__resources-item global-footer__resources-item--safety-center">
# <a class="global-footer__link global-footer__link--static t-12 t-bold ember-view" data-control-name="globalfooter.safety_center" href="https://safety.linkedin.com" id="globalfooter-safety_center" rel="noopener noreferrer" target="_blank"> <span>Safety Center</span>
# </a> </li>
# </ul>
# </nav>
# <div class="global-footer__actions">
# <ul class="global-footer__actions-list" id="footer-action-list">
# <li class="global-footer__actions-list-item">
# <li-icon active="true" aria-hidden="true" class="global-footer__action-icon" color="true" type="question-pebble-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="large-icon" d="M12,2C6.5,2,2,6.5,2,12s4.5,10,10,10c5.5,0,10-4.5,10-10S17.5,2,12,2zM12,20.2c-4.5,0-8.2-3.7-8.2-8.2S7.5,3.8,12,3.8c4.5,0,8.2,3.7,8.2,8.2S16.5,20.2,12,20.2zM11,16h2v2h-2V16zM16,9.3V10c0,1.7-1.3,2.9-3,2.9V14h-2v-1c0-1.1,0.9-2,2-2h0.3c0.5,0,0.9-0.4,0.9-0.9v-1.3c0-0.5-0.4-0.9-0.9-0.9h-2.6c-0.5,0-0.9,0.4-0.9,0.9V10H8V9.3C8,7.5,9.5,6,11.3,6h1.5C14.5,6,16,7.5,16,9.3z" style="fill: currentColor"></path></svg></li-icon>
# <div class="global-footer__action-container">
# <a class="global-footer__link global-footer__link--static t-14 t-bold ember-view" data-control-name="globalfooter.questions" href="https://www.linkedin.com/help/linkedin?trk=d_flagship3_profile_view_base" id="globalfooter-questions" rel="noopener noreferrer" target="_blank">                        Questions?
# </a> <p class="global-footer__label t-12">Visit our Help Center.</p>
# </div>
# </li>
# <li class="global-footer__actions-list-item">
# <li-icon active="true" aria-hidden="true" class="global-footer__action-icon" color="true" type="gear-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="large-icon" d="M12,9a3,3,0,1,0,3,3A3,3,0,0,0,12,9Zm0,5.13A2.13,2.13,0,1,1,14.12,12,2.12,2.12,0,0,1,12,14.13Zm7.91-2.87L22,9.38,19.26,4.62,16.6,5.5a1,1,0,0,1-1.29-.75L14.74,2H9.26L8.69,4.75A1,1,0,0,1,7.4,5.5L4.74,4.62,2,9.38l2.09,1.87a1,1,0,0,1,0,1.49L2,14.62l2.74,4.76L7.4,18.5a1,1,0,0,1,1.29.75L9.26,22h5.48l0.57-2.75a1,1,0,0,1,1.29-.75l2.66,0.88L22,14.62l-2.09-1.87A1,1,0,0,1,19.91,11.25ZM18.4,17.12l-1.22-.4a2.86,2.86,0,0,0-3.7,2.14l-0.26,1.26H10.78l-0.26-1.26a2.86,2.86,0,0,0-3.7-2.14l-1.22.4L4.38,15l1-.86a2.88,2.88,0,0,0,0-4.29L4.38,9,5.6,6.88l1.22,0.4a2.86,2.86,0,0,0,3.7-2.14l0.26-1.26h2.44l0.26,1.26a2.86,2.86,0,0,0,3.7,2.14l1.22-.4L19.62,9l-1,.86a2.88,2.88,0,0,0,0,4.29l1,0.86Z" style="fill: currentColor"></path></svg></li-icon>
# <div class="global-footer__action-container">
# <a class="global-footer__link global-footer__link--static t-14 t-bold ember-view" data-control-name="globalfooter.manage_account" href="https://www.linkedin.com/psettings/" id="globalfooter-manage_account" rel="noopener noreferrer" target="_blank">                        Manage your account and privacy.
# </a> <p class="global-footer__label t-12">Go to your Settings.</p>
# </div>
# </li>
# </ul>
# <div class="global-footer__language-selection">
# <label class="global-footer__label t-12 t-normal mb1 mt0" for="globalfooter-select_language">
#                 Select Language
#               </label>
# <div class="ember-view" id="ember312"><select class="global-footer__language-selection-dropdown t-12 t-black--light t-bold" id="globalfooter-select_language">
# <option lang="in-ID" value="in_ID">Bahasa Indonesia (Bahasa Indonesia)</option>
# <option lang="ms-MY" value="ms_MY">Bahasa Malaysia (Malay)</option>
# <option lang="cs-CZ" value="cs_CZ">Čeština (Czech)</option>
# <option lang="da-DK" value="da_DK">Dansk (Danish)</option>
# <option lang="de-DE" value="de_DE">Deutsch (German)</option>
# <option lang="en-US" value="en_US">English (English)</option>
# <option lang="es-ES" value="es_ES">Español (Spanish)</option>
# <option lang="zh-TW" value="zh_TW">正體中文 (Chinese (Traditional))</option>
# <option lang="fr-FR" value="fr_FR">Français (French)</option>
# <option lang="ko-KR" value="ko_KR">한국어 (Korean)</option>
# <option lang="it-IT" value="it_IT">Italiano (Italian)</option>
# <option lang="zh-CN" value="zh_CN">简体中文 (Chinese (Simplified))</option>
# <option lang="nl-NL" value="nl_NL">Nederlands (Dutch)</option>
# <option lang="ja-JP" value="ja_JP">日本語 (Japanese)</option>
# <option lang="no-NO" value="no_NO">Norsk (Norwegian)</option>
# <option lang="pl-PL" value="pl_PL">Polski (Polish)</option>
# <option lang="pt-BR" value="pt_BR">Português (Portuguese)</option>
# <option lang="ro-RO" value="ro_RO">Română (Romanian)</option>
# <option lang="ru-RU" value="ru_RU">Русский (Russian)</option>
# <option lang="sv-SE" value="sv_SE">Svenska (Swedish)</option>
# <option lang="tl-PH" value="tl_PH">Tagalog (Tagalog)</option>
# <option lang="th-TH" value="th_TH">ภาษาไทย (Thai)</option>
# <option lang="tr-TR" value="tr_TR">Türkçe (Turkish)</option>
# <option lang="ar-AE" value="ar_AE">العربية (Arabic)</option>
# </select>
# </div>
# </div>
# </div>
# </div>
# <p class="t-12 t-black--light t-normal text-align-left clear-both" id="globalfooter-copyright">
#           LinkedIn Corporation © 2019
#         </p>
# </div>
# </div>
# </div></footer>
# </div>
# </div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# </div>
# </div>
# <aside class="msg-overlay-container ember-view" id="msg-overlay"><!-- -->
# <div class="mh4 msg-overlay-list-bubble msg-overlay-list-bubble--is-minimized msg-overlay-discoverability-color msg-overlay-discoverability-photo ember-view" id="ember158" tabindex="-1"><header class="msg-overlay-bubble-header" data-control-name="overlay.maximize_connection_list_bar" data-ember-action="" data-ember-action-159="159">
# <div class="ember-view" id="ember160"><!-- --></div>
# <section class="msg-overlay-bubble-header__details flex-row align-items-center">
# <div class="presence-entity presence-entity--size-1 ember-view" id="ember161"><img alt="KGP Talkie" class="presence-entity__image EntityPhoto-circle-1 lazy-image loaded ember-view" id="ember162" src="https://media.licdn.com/dms/image/C5103AQEkJUJ02qVLEw/profile-displayphoto-shrink_100_100/0?e=1575504000&amp;v=beta&amp;t=6LbVOj1WmX_AQAEoNqZ0YmA7s7UP4-phBh16YbHdmmk"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-1 presence-indicator presence-indicator--is-online presence-indicator--size-1 ember-view" id="ember163">
# <span class="visually-hidden">
#     Status is online
# </span>
# </div>
# </div>
# <button class="msg-overlay-bubble-header__button truncate ml2">
# <h4 class="msg-overlay-bubble-header__primary-text truncate t-14 t-black t-bold">
# <span aria-hidden="true">Messaging</span>
# <span class="visually-hidden">
#             You are on the messaging overlay. Press enter to open the list of conversations.
#           </span>
# </h4>
# </button>
# <!-- -->
# <!-- --> </section>
# <section class="msg-overlay-bubble-header__controls display-flex">
# <button class="msg-overlay-bubble-header__control msg-overlay-bubble-header__control--new-convo-btn artdeco-button artdeco-button--circle artdeco-button--inverse artdeco-button--1 artdeco-button--tertiary ember-view" data-control-name="overlay.compose_message" id="ember164"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="compose-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="small-icon" d="M11,8.75l2-2V13a1,1,0,0,1-1,1H3a1,1,0,0,1-1-1V4A1,1,0,0,1,3,3H9.25l-2,2H4v7h7V8.75ZM6,8.59L5,11l2.41-1L12.9,4.52,11.48,3.1Zm8.85-6.73-0.71-.71a0.5,0.5,0,0,0-.71,0L12.25,2.34l1.41,1.41,1.19-1.19A0.5,0.5,0,0,0,14.85,1.85Z" style="fill-opacity: 1"></path></svg></li-icon>
# <span class="artdeco-button__text">
#     Compose message
# </span></button>
# <!-- --><artdeco-dropdown class="ember-view" id="ember165"><artdeco-dropdown-trigger aria-expanded="false" class="artdeco-button artdeco-button--1 artdeco-button--circle artdeco-button--tertiary artdeco-button--inverse ember-view" data-control-name="overlay.dropdown_menu" id="ember166" placement="top" role="button" tabindex="0"> <li-icon aria-hidden="true" color="true" size="small" type="ellipsis-horizontal-icon"><svg class="artdeco-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" y="0"><path class="small-icon" d="M2,7H4V9H2V7ZM7,9H9V7H7V9Zm5-2V9h2V7H12Z" style="fill-opacity: 1"></path></svg></li-icon>
# <!-- --></artdeco-dropdown-trigger> <div class="msg-overlay-bubble-header__dropdown-container">
# <artdeco-dropdown-content aria-hidden="true" arrow-dir="right" class="artdeco-dropdown-with-arrow ember-view" data-dropdown="" id="ember167" justification="right" placement="top" tabindex="-1"> <ul class="white-space-nowrap">
# <artdeco-dropdown-item class="ember-view" data-control-name="overlay.compose_group_from_dropdown" data-dropdown="" id="ember168" tabindex="0"><!-- -->                New group conversation
# </artdeco-dropdown-item>
# <!-- -->
# <artdeco-dropdown-item class="ember-view" data-control-name="overlay.connection_list_settings_from_dropdown" data-dropdown="" id="ember169" tabindex="0"><!-- -->                Messaging settings
# </artdeco-dropdown-item> </ul>
# </artdeco-dropdown-content> </div>
# </artdeco-dropdown> </section>
# </header>
# <!-- -->
# <section class="msg-overlay-list-bubble__content msg-overlay-list-bubble__content--scrollable">
# <!-- --></section>
# <!-- -->
# </div>
# <!-- --></aside>
# <!-- -->
# <img class="third-party-tracking-pixel hidden ember-view" id="ember38" src="https://px.ads.linkedin.com/setuid?partner=google&amp;_t=1569944458116"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"></div>
# <!-- -->
# <!-- -->
# <div class="ember-view" id="ember39"><div class="ember-view" id="ember40"><!-- --></div></div>
# <div class="entity-hovercard-container hidden ember-view" id="ember41"><div class="entity-hovercard" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div>
# </div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <iframe sandbox="allow-scripts" src="//radar.cedexis.com/1/11326/radar.html" style="display:none;">
# </iframe>
# </div><code id="bpr-guid-2140239" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:yA89Nr+/JVYQ5kTiinj9ycvKUqdCZ8pNOQ7V+ufBUZ8=","elements":[],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140239" style="display: none">
#   {"request":"/voyager/api/identity/profiles/rishabh-singh-61b706114/treasuryMediaItems?q\u003DbackgroundMedia\u0026section\u003DEDUCATION","status":200,"body":"bpr-guid-2140239"}
# </code>
# <img class="datalet-bpr-guid-2140239" src="..." style="display: none"/><code id="bpr-guid-2140240" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:WxLZKtwUfijbly4gZ6SF5jKJX2svJ7wHBxtUmFHOlkE=","elements":[],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2140240" style="display: none">
#   {"request":"/voyager/api/identity/profiles/rishabh-singh-61b706114/promoVisibility?contextType\u003DNON_SELF_PROFILE_VIEW\u0026promoTypes\u003DList(NON_SELF_PROFILE_PROMOTION,SUGGESTED_ENDORSEMENTS,APP_DOWNLOAD)\u0026q\u003DfindActivePromos\u0026vieweeMemberId\u003Drishabh-singh-61b706114","status":200,"body":"bpr-guid-2140240"}
# </code>
# <img class="datalet-bpr-guid-2140240" src="..." style="display: none"/><code id="clientPageInstance" style="display: none">
#   urn:li:page:d_flagship3_profile_view_base;qOR554UYRP623LiOSKrOaQ==
# </code>
# <img class="terminatorlet" src="..." style="display: none"/>
# <div aria-live="polite" class="visually-hidden" id="a11y-notification" role="region"></div>
# </body></html>

# %%
name_div = soup.find('div', {'class': 'flex-1 mr5'})
name_div
# Out:
# <div class="flex-1 mr5">
# <ul class="pv-top-card-v3--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Rishabh Singh
#           </li>
# <li class="pv-top-card-v3__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">3rd degree connection</span><span aria-hidden="true" class="dist-value">3rd</span>
# </span></li>
# <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card-v3 inline-flex pv-member-badge ember-view" id="ember88" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Rishabh has a  account
# </span>
# <!-- --></span>
# </li>
# </ul>
# <h2 class="mt1 t-18 t-black t-normal">
#             FPGA Engineer at Honeywell
#           </h2>
# <ul class="pv-top-card-v3--list pv-top-card-v3--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               Bengaluru, Karnataka, India
#             </li>
# <!-- -->
# <li class="inline-block">
# <span class="t-16 t-black t-normal">
#                   500+ connections
#                 </span>
# </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/rishabh-singh-61b706114/detail/contact-info/" id="ember89"> <span class="t-16 t-bold">
#                 Contact info
#               </span>
# </a> </li>
# </ul>
# </div>

# %%
name_loc = name_div.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'Rishabh Singh'

# %%
loc = name_loc[1].find('li').get_text().strip()
loc
# Out:
# 'Bengaluru, Karnataka, India'

# %%
profile_title = name_div.find('h2').get_text().strip()
profile_title
# Out:
# 'FPGA Engineer at Honeywell'

# %%
connection = name_loc[1].find_all('li')
connection = connection[1].get_text().strip()
connection
# Out:
# '500+ connections'

# %%
info = []
info.append(link)
info.append(name)
info.append(profile_title)
info.append(loc)
info.append(connection)
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  'FPGA Engineer at Honeywell',
#  'Bengaluru, Karnataka, India',
#  '500+ connections']

# %% [markdown]
# ### Experience

# %%
exp_section = soup.find('section', {'id': 'experience-section'})
exp_section
# Out:
# <section class="pv-profile-section experience-section ember-view" id="experience-section"><header class="pv-profile-section__card-header">
# <h2 class="pv-profile-section__card-heading">
#     Experience
#   </h2>
# <!-- --></header>
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <div class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember126"> <li class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1517647779"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/1344/" id="ember129"> <div class="pv-entity__logo company-logo">
# <img alt="Honeywell" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image loaded ember-view" id="ember131" src="https://media.licdn.com/dms/image/C560BAQFvcIh3UnA5zw/company-logo_400_400/0?e=1577923200&amp;v=beta&amp;t=Md9vGidkpD4D9HVB4mxqI-y_rceccCfrSCeFOxZc1w4"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">Honeywell</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Aug 2019 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">3 mos</span>
# </h4>
# </div>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <!-- --> </div>
# </li>
# </div><div class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember134"> <li class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="929137672"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/1739031/" id="ember137"> <div class="pv-entity__logo company-logo">
# <img alt="L&amp;T Technology Services Limited" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image loaded ember-view" id="ember139" src="https://media.licdn.com/dms/image/C4E0BAQHxZH7KRvUrrg/company-logo_400_400/0?e=1577923200&amp;v=beta&amp;t=HLOQa1f5kqBaw49r4k4NtRBrJaEJX0Mjy2ZKu54oz9M"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Design Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">L&amp;T Technology Services Limited</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Jan 2017 – Jul 2019</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">2 yrs 7 mos</span>
# </h4>
# </div>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <!-- --> </div>
# </li>
# </div> </ul>
# <!-- --></section>

# %%
exp_section = exp_section.find('ul')
li_tags = exp_section.find('div')
a_tags = li_tags.find('a')

# %%
a_tags
# Out:
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/1344/" id="ember129"> <div class="pv-entity__logo company-logo">
# <img alt="Honeywell" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image loaded ember-view" id="ember131" src="https://media.licdn.com/dms/image/C560BAQFvcIh3UnA5zw/company-logo_400_400/0?e=1577923200&amp;v=beta&amp;t=Md9vGidkpD4D9HVB4mxqI-y_rceccCfrSCeFOxZc1w4"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">FPGA Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">Honeywell</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Aug 2019 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">3 mos</span>
# </h4>
# </div>
# <!-- -->
# </div>
# </a>

# %%
job_title = a_tags.find('h3').get_text().strip()
job_title
# Out:
# 'FPGA Engineer'

# %%
company_name = a_tags.find_all('p')[1].get_text().strip()
company_name
# Out:
# 'Honeywell'

# %%
joining_date = a_tags.find_all('h4')[0].find_all('span')[1].get_text().strip()
joining_date
# Out:
# 'Aug 2019 – Present'

# %%
exp = a_tags.find_all('h4')[1].find_all('span')[1].get_text().strip()
exp
# Out:
# '3 mos'

# %%
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  'FPGA Engineer at Honeywell',
#  'Bengaluru, Karnataka, India',
#  '500+ connections']

# %%
info.append(company_name)
info.append(job_title)
info.append(joining_date)
info.append(exp)

# %%
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  'FPGA Engineer at Honeywell',
#  'Bengaluru, Karnataka, India',
#  '500+ connections',
#  'Honeywell',
#  'FPGA Engineer',
#  'Aug 2019 – Present',
#  '3 mos']

# %% [markdown]
# ### Education

# %%
edu_section = soup.find('section', {'id': 'education-section'}).find('ul')
edu_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more ember-view" id="ember143"><li class="pv-profile-section__sortable-item pv-profile-section__section-info-item relative pv-profile-section__sortable-item--v2 pv-profile-section__list-item sortable-item ember-view" id="ember145"> <div class="pv-profile-section__sortable-card-item pv-education-entity pv-profile-section__card-item ember-view" id="356637700"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/school/223389/?legacySchoolId=223389" id="ember147"> <div class="pv-entity__logo">
# <img alt="Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school loaded ember-view" id="ember149" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">Bachelor of Engineering (B.E.)</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">Electrical, Electronics and Communications Engineering</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__grade t-14 t-black t-normal">
# <span class="visually-hidden">Grade</span>
# <span class="pv-entity__comma-item">FIRST</span>
# </p>
# </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2012</time> – <time>2016</time>
# </span>
# </p>
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </div>
# </li><li class="pv-profile-section__sortable-item pv-profile-section__section-info-item relative pv-profile-section__sortable-item--v2 pv-profile-section__list-item sortable-item ember-view" id="ember151"> <div class="pv-profile-section__sortable-card-item pv-education-entity pv-profile-section__card-item ember-view" id="373985416"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/search/results/index/?keywords=S.H.S.B.B" id="ember153"> <div class="pv-entity__logo">
# <img alt="S.H.S.B.B" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school loaded ember-view" id="ember155" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">S.H.S.B.B</h3>
# <!-- --> <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">PCM</span>
# </p>
# <!-- --> </div>
# <!-- -->
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </div>
# </li>
# </ul>

# %%
college_name = edu_section.find('h3').get_text().strip()
college_name
# Out:
# 'Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021'

# %%
degree_name = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
degree_name
# Out:
# 'Bachelor of Engineering (B.E.)'

# %%
stream = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
stream
# Out:
# 'Electrical, Electronics and Communications Engineering'

# %%
degree_year = edu_section.find('p', {'class': 'pv-entity__dates t-14 t-black--light t-normal'}).find_all('span')[1].get_text().strip()
degree_year
# Out:
# '2012 – 2016'

# %%
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  'FPGA Engineer at Honeywell',
#  'Bengaluru, Karnataka, India',
#  '500+ connections',
#  'Honeywell',
#  'FPGA Engineer',
#  'Aug 2019 – Present',
#  '3 mos']

# %%
info.append(college_name)
info.append(degree_name)
info.append(stream)
info.append(degree_year)

# %%
info
# Out:
# ['https://www.linkedin.com/in/rishabh-singh-61b706114/',
#  'Rishabh Singh',
#  'FPGA Engineer at Honeywell',
#  'Bengaluru, Karnataka, India',
#  '500+ connections',
#  'Honeywell',
#  'FPGA Engineer',
#  'Aug 2019 – Present',
#  '3 mos',
#  'Technocrats Institute of Technology (Excellence), Anand Nagar, PB No. 24, Post Piplani, BHEL, Bhopal - 462021',
#  'Bachelor of Engineering (B.E.)',
#  'Electrical, Electronics and Communications Engineering',
#  '2012 – 2016']
